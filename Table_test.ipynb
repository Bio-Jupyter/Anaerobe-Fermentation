# %% [markdown]
# ![image.png](attachment:217f013f-e140-4f7e-9aab-0572ff5b1f6f.png)

# %%
# %run resources/table_data.ipynb
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_20828\2493384982.py:39
#      36         od_widgets[i].value = df.at[i, 'OD']
#      38 # Load initial data from CSV to set up widgets
# ---> 39 initial_df = pd.read_csv('lab_data.csv')
#      41 # Add the new columns to the DataFrame if they don't exist
#      42 columns_to_add = ['Trocken-biomasse', 'Gesamt-Zellzahl', 'Lebendzellzahl', 'OD']
#
# ...

# %%
# %run resources/plot_gesamtzellzahl_vs_time.ipynb

# %%
# %run resources/plot_od_vs_time.ipynb
